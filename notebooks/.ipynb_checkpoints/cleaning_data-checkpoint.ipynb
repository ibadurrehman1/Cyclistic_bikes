# %% [markdown]
# # Importing Libraries

# %%
# importing Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Loading Data

# %%
# reading data
main_df=pd.read_csv('../datasets/main_df.csv')
main_df.head()
# Out:
#    Unnamed: 0           ride_id  rideable_type           started_at  \
# 0           0  C2F7DD78E82EC875  electric_bike  2022-01-13 11:59:47
# 1           1  A6CF8980A652D272  electric_bike  2022-01-10 08:41:56
# 2           2  BD0F91DFF741C66D   classic_bike  2022-01-25 04:53:40
# 3           3  CBB80ED419105406   classic_bike  2022-01-04 00:18:04
# 4           4  DDC963BFDDA51EEA   classic_bike  2022-01-20 01:31:10
#
#               ended_at             start_station_name start_station_id  \
# 0  2022-01-13 12:02:44       Glenwood Ave & Touhy Ave              525
# 1  2022-01-10 08:46:17       Glenwood Ave & Touhy Ave              525
# 2  2022-01-25 04:58:01  Sheffield Ave & Fullerton Ave     TA1306000016
# 3  2022-01-04 00:33:00       Clark St & Bryn Mawr Ave     KA1504000151
# 4  2022-01-20 01:37:12    Michigan Ave & Jackson Blvd     TA1309000002
#
#                 end_station_name end_station_id  start_lat  start_lng  \
# 0           Clark St & Touhy Ave         RP-007  42.012800 -87.665906
# 1           Clark St & Touhy Ave         RP-007  42.012763 -87.665967
# 2  Greenview Ave & Fullerton Ave   TA1307000001  41.925602 -87.653708
# 3      Paulina St & Montrose Ave   TA1309000021  41.983593 -87.669154
# 4         State St & Randolph St   TA1305000029  41.877850 -87.624080
#
#      end_lat    end_lng member_casual
# 0  42.012560 -87.674367        casual
# 1  42.012560 -87.674367        casual
# 2  41.925330 -87.665800        member
# 3  41.961507 -87.671387        casual
# 4  41.884621 -87.627834        member

# %% [markdown]
# Unnamed:0 is just the duplicate of index of datasets. So we dont need it.

# %%
main_df.drop('Unnamed: 0', inplace=True, axis=1)
main_df
# Out:
#                   ride_id  rideable_type           started_at  \
# 0        C2F7DD78E82EC875  electric_bike  2022-01-13 11:59:47
# 1        A6CF8980A652D272  electric_bike  2022-01-10 08:41:56
# 2        BD0F91DFF741C66D   classic_bike  2022-01-25 04:53:40
# 3        CBB80ED419105406   classic_bike  2022-01-04 00:18:04
# 4        DDC963BFDDA51EEA   classic_bike  2022-01-20 01:31:10
# ...                   ...            ...                  ...
# 5667981  847431F3D5353AB7  electric_bike  2021-12-12 13:36:55
# 5667982  CF407BBC3B9FAD63  electric_bike  2021-12-06 19:37:50
# 5667983  60BB69EBF5440E92  electric_bike  2021-12-02 08:57:04
# 5667984  C414F654A28635B8  electric_bike  2021-12-13 09:00:26
# 5667985  37AC57E34B2E7E97   classic_bike  2021-12-13 08:45:32
#
#                     ended_at             start_station_name start_station_id  \
# 0        2022-01-13 12:02:44       Glenwood Ave & Touhy Ave              525
# 1        2022-01-10 08:46:17       Glenwood Ave & Touhy Ave              525
# 2        2022-01-25 04:58:01  Sheffield Ave & Fullerton Ave     TA1306000016
# 3        2022-01-04 00:33:00       Clark St & Bryn Mawr Ave     KA1504000151
# 4        2022-01-20 01:37:12    Michigan Ave & Jackson Blvd     TA1309000002
# ...                      ...                            ...              ...
# 5667981  2021-12-12 13:56:08          Canal St & Madison St            13341
# 5667982  2021-12-06 19:44:51          Canal St & Madison St            13341
# 5667983  2021-12-02 09:05:21          Canal St & Madison St            13341
# 5667984  2021-12-13 09:14:39         Lawndale Ave & 16th St            362.0
# 5667985  2021-12-13 08:49:09    Michigan Ave & Jackson Blvd     TA1309000002
#
#                       end_station_name end_station_id  start_lat  start_lng  \
# 0                 Clark St & Touhy Ave         RP-007  42.012800 -87.665906
# 1                 Clark St & Touhy Ave         RP-007  42.012763 -87.665967
# 2        Greenview Ave & Fullerton Ave   TA1307000001  41.925602 -87.653708
# 3            Paulina St & Montrose Ave   TA1309000021  41.983593 -87.669154
# 4               State St & Randolph St   TA1305000029  41.877850 -87.624080
# ...                                ...            ...        ...        ...
# 5667981                            NaN            NaN  41.882289 -87.639752
# 5667982       Kingsbury St & Kinzie St   KA1503000043  41.882123 -87.640053
# 5667983        Dearborn St & Monroe St   TA1305000006  41.881956 -87.639955
# 5667984                            NaN            NaN  41.860000 -87.720000
# 5667985        Dearborn St & Monroe St   TA1305000006  41.877850 -87.624080
#
#            end_lat    end_lng member_casual
# 0        42.012560 -87.674367        casual
# 1        42.012560 -87.674367        casual
# 2        41.925330 -87.665800        member
# 3        41.961507 -87.671387        casual
# 4        41.884621 -87.627834        member
# ...            ...        ...           ...
# 5667981  41.890000 -87.610000        casual
# 5667982  41.889106 -87.638862        member
# 5667983  41.880254 -87.629603        member
# 5667984  41.850000 -87.710000        member
# 5667985  41.881320 -87.629521        member
#
# [5667986 rows x 13 columns]

# %% [markdown]
# Making a copy of original dataset to perform cleaning. so that raw data can also be retreive whermever needed

# %%
used_df_v1=main_df.copy()

# %%
used_df_v1.head(1)
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  C2F7DD78E82EC875  electric_bike  2022-01-13 11:59:47  2022-01-13 12:02:44
#
#          start_station_name start_station_id      end_station_name  \
# 0  Glenwood Ave & Touhy Ave              525  Clark St & Touhy Ave
#
#   end_station_id  start_lat  start_lng   end_lat    end_lng member_casual
# 0         RP-007    42.0128 -87.665906  42.01256 -87.674367        casual

# %% [markdown]
# # Data Information

# %%
used_df_v1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5667986 entries, 0 to 5667985
# Data columns (total 13 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          object
#  3   ended_at            object
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
# dtypes: float64(4), object(9)
# memory usage: 562.2+ MB

# %% [markdown]
# Datatype of Date column are in **object** datatype

# %% [markdown]
# # Changing Datatypes

# %% [markdown]
# Changing datatype of **started_at** and **ended_at** to **Datatime**

# %%
date_related_columns=['started_at','ended_at']

for i in range(len(date_related_columns)):
    j=date_related_columns[i]
    used_df_v1[j]=pd.to_datetime(used_df_v1[j])

# %%
used_df_v1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5667986 entries, 0 to 5667985
# Data columns (total 13 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          datetime64[ns]
#  3   ended_at            datetime64[ns]
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
# dtypes: datetime64[ns](2), float64(4), object(7)
# memory usage: 562.2+ MB

# %% [markdown]
# # Creating New Columns

# %%
used_df_v1['duration_of_ride_sec'] = (used_df_v1.ended_at - used_df_v1.started_at).dt.total_seconds()

# %%
used_df_v1['minute']=((used_df_v1.duration_of_ride_sec//60).astype('int64')).astype(str)

# %%
used_df_v1['second']=((used_df_v1.duration_of_ride_sec%60).astype('int64')).astype(str)

# %%
used_df_v1['duration_of_ride_min']= used_df_v1[['minute', 'second']].agg('.'.join, axis=1)

# %%
used_df_v1['duration_of_ride_min']=used_df_v1['duration_of_ride_min'].astype('float64')

# %%
used_df_v1.head()
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  C2F7DD78E82EC875  electric_bike 2022-01-13 11:59:47 2022-01-13 12:02:44
# 1  A6CF8980A652D272  electric_bike 2022-01-10 08:41:56 2022-01-10 08:46:17
# 2  BD0F91DFF741C66D   classic_bike 2022-01-25 04:53:40 2022-01-25 04:58:01
# 3  CBB80ED419105406   classic_bike 2022-01-04 00:18:04 2022-01-04 00:33:00
# 4  DDC963BFDDA51EEA   classic_bike 2022-01-20 01:31:10 2022-01-20 01:37:12
#
#               start_station_name start_station_id  \
# 0       Glenwood Ave & Touhy Ave              525
# 1       Glenwood Ave & Touhy Ave              525
# 2  Sheffield Ave & Fullerton Ave     TA1306000016
# 3       Clark St & Bryn Mawr Ave     KA1504000151
# 4    Michigan Ave & Jackson Blvd     TA1309000002
#
#                 end_station_name end_station_id  start_lat  start_lng  \
# 0           Clark St & Touhy Ave         RP-007  42.012800 -87.665906
# 1           Clark St & Touhy Ave         RP-007  42.012763 -87.665967
# 2  Greenview Ave & Fullerton Ave   TA1307000001  41.925602 -87.653708
# 3      Paulina St & Montrose Ave   TA1309000021  41.983593 -87.669154
# 4         State St & Randolph St   TA1305000029  41.877850 -87.624080
#
#      end_lat    end_lng member_casual  duration_of_ride_sec minute second  \
# 0  42.012560 -87.674367        casual                 177.0      2     57
# 1  42.012560 -87.674367        casual                 261.0      4     21
# 2  41.925330 -87.665800        member                 261.0      4     21
# 3  41.961507 -87.671387        casual                 896.0     14     56
# 4  41.884621 -87.627834        member                 362.0      6      2
#
#    duration_of_ride_min
# 0                  2.57
# 1                  4.21
# 2                  4.21
# 3                 14.56
# 4                  6.20

# %%
used_df_v1['ride_start_in_years']=used_df_v1.started_at.dt.year
used_df_v1['ride_start_in_month'] = used_df_v1.started_at.dt.month_name()
used_df_v1['ride_start_in_quarter'] = used_df_v1.started_at.dt.quarter
used_df_v1['ride_start_in_weekday'] = used_df_v1.started_at.dt.day_name()

# %%
used_df_v1.drop(['minute','second'], axis = 1,inplace = True)

# %%
used_df_v1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5667986 entries, 0 to 5667985
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ride_id                object
#  1   rideable_type          object
#  2   started_at             datetime64[ns]
#  3   ended_at               datetime64[ns]
#  4   start_station_name     object
#  5   start_station_id       object
#  6   end_station_name       object
#  7   end_station_id         object
#  8   start_lat              float64
#  9   start_lng              float64
#  10  end_lat                float64
#  11  end_lng                float64
#  12  member_casual          object
#  13  duration_of_ride_sec   float64
#  14  duration_of_ride_min   float64
#  15  ride_start_in_years    int64
#  16  ride_start_in_month    object
#  17  ride_start_in_quarter  int64
#  18  ride_start_in_weekday  object
# dtypes: datetime64[ns](2), float64(6), int64(2), object(9)
# memory usage: 821.6+ MB

# %% [markdown]
# Pandas does not have any built-it method to extract the week of month.
# So, I am using function created by [Jan](https://stackoverflow.com/users/6089311/jan)
#
# He also in-Depth explain the whole function in his answer to the [Question](https://stackoverflow.com/questions/25249033/week-of-a-month-pandas#:~:text=Now%20I%20can%20calculate%20with,calculation%20df%5B'Date'%5D
# )

# %%
def weekinmonth(dates):
    """Get week number in a month.
    
    Parameters: 
        dates (pd.Series): Series of dates.
    Returns: 
        pd.Series: Week number in a month.
    """
    firstday_in_month = dates - pd.to_timedelta(dates.dt.day - 1, unit='d')
    return (dates.dt.day-1 + firstday_in_month.dt.weekday) // 7 + 1

# %%
used_df_v1['ride_start_in_weekofmonth']=weekinmonth(used_df_v1['started_at'])

# %%
used_df_v1.head(1)
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  C2F7DD78E82EC875  electric_bike 2022-01-13 11:59:47 2022-01-13 12:02:44
#
#          start_station_name start_station_id      end_station_name  \
# 0  Glenwood Ave & Touhy Ave              525  Clark St & Touhy Ave
#
#   end_station_id  start_lat  start_lng   end_lat    end_lng member_casual  \
# 0         RP-007    42.0128 -87.665906  42.01256 -87.674367        casual
#
#    duration_of_ride_sec  duration_of_ride_min  ride_start_in_years  \
# 0                 177.0                  2.57                 2022
#
#   ride_start_in_month  ride_start_in_quarter ride_start_in_weekday  \
# 0             January                      1              Thursday
#
#    ride_start_in_weekofmonth
# 0                          3

# %% [markdown]
# # Cleaning Data

# %% [markdown]
# ### Extracting Columns having negative or zero Ride Duration.

# %% [markdown]
# Checking for rows having starting time of ride greater than ending time.

# %%
used_df_v1[used_df_v1.duration_of_ride_sec<=0]
# Out:
#                   ride_id  rideable_type          started_at  \
# 21591    C2E047DDF019C255  electric_bike 2022-01-18 19:25:42
# 81320    8D3E8E511FEB11CC  electric_bike 2022-01-21 01:05:35
# 97019    A753A729011B4289  electric_bike 2022-01-09 10:39:48
# 97365    0C63D14D261205FA  electric_bike 2022-01-28 15:28:11
# 99658    4B0FC5ACEE52EBF9  electric_bike 2022-01-18 19:38:26
# ...                   ...            ...                 ...
# 5647024  0A0682829241BE7E  electric_bike 2021-12-03 17:10:39
# 5652341  097BCE7BCAC82D5A  electric_bike 2021-12-31 17:24:52
# 5652384  7D9F6FD8AA55A78D  electric_bike 2021-12-05 11:41:27
# 5658774  B56D8E85B23B672F  electric_bike 2021-12-03 16:57:36
# 5659905  0491DF902148BE58  electric_bike 2021-12-09 19:01:40
#
#                    ended_at              start_station_name start_station_id  \
# 21591   2022-01-18 19:25:42           Green St & Madison St     TA1307000120
# 81320   2022-01-21 01:05:35     Western Ave & Winnebago Ave            13068
# 97019   2022-01-09 10:39:48        Clark St & Bryn Mawr Ave     KA1504000151
# 97365   2022-01-28 15:28:11           Wells St & Hubbard St     TA1307000151
# 99658   2022-01-18 19:38:26  Sheffield Ave & Wrightwood Ave     TA1309000023
# ...                     ...                             ...              ...
# 5647024 2021-12-03 17:10:39            Racine Ave & 18th St            13164
# 5652341 2021-12-31 17:24:52         Streeter Dr & Grand Ave            13022
# 5652384 2021-12-05 11:41:27             Ellis Ave & 60th St     KA1503000014
# 5658774 2021-12-03 16:57:36           Michigan Ave & Oak St            13042
# 5659905 2021-12-09 19:01:40                             NaN              NaN
#
#         end_station_name end_station_id  start_lat  start_lng  end_lat  \
# 21591                NaN            NaN  41.881783 -87.648608    41.88
# 81320                NaN            NaN  41.915525 -87.687039    41.92
# 97019                NaN            NaN  41.983567 -87.669127    41.98
# 97365                NaN            NaN  41.890174 -87.634231    41.89
# 99658                NaN            NaN  41.928670 -87.653789    41.93
# ...                  ...            ...        ...        ...      ...
# 5647024              NaN            NaN  41.858251 -87.656440    41.86
# 5652341              NaN            NaN  41.892234 -87.611931    41.89
# 5652384              NaN            NaN  41.785075 -87.601089    41.79
# 5658774              NaN            NaN  41.900970 -87.623778    41.90
# 5659905              NaN            NaN  41.790000 -87.600000    41.79
#
#          end_lng member_casual  duration_of_ride_sec  duration_of_ride_min  \
# 21591     -87.65        member                   0.0                   0.0
# 81320     -87.69        casual                   0.0                   0.0
# 97019     -87.67        member                   0.0                   0.0
# 97365     -87.63        casual                   0.0                   0.0
# 99658     -87.65        casual                   0.0                   0.0
# ...          ...           ...                   ...                   ...
# 5647024   -87.66        casual                   0.0                   0.0
# 5652341   -87.61        casual                   0.0                   0.0
# 5652384   -87.60        member                   0.0                   0.0
# 5658774   -87.62        casual                   0.0                   0.0
# 5659905   -87.60        member                   0.0                   0.0
#
#          ride_start_in_years ride_start_in_month  ride_start_in_quarter  \
# 21591                   2022             January                      1
# 81320                   2022             January                      1
# 97019                   2022             January                      1
# 97365                   2022             January                      1
# 99658                   2022             January                      1
# ...                      ...                 ...                    ...
# 5647024                 2021            December                      4
# 5652341                 2021            December                      4
# 5652384                 2021            December                      4
# 5658774                 2021            December                      4
# 5659905                 2021            December                      4
#
#         ride_start_in_weekday  ride_start_in_weekofmonth
# 21591                 Tuesday                          4
# 81320                  Friday                          4
# 97019                  Sunday                          2
# 97365                  Friday                          5
# 99658                 Tuesday                          4
# ...                       ...                        ...
# 5647024                Friday                          1
# 5652341                Friday                          5
# 5652384                Sunday                          1
# 5658774                Friday                          1
# 5659905              Thursday                          2
#
# [653 rows x 20 columns]

# %% [markdown]
# Dataset have **653 rows** which have Duration of Ride **Less than equal to** zero.
# This data rows are inaccurate because
# - Duration of ride can not be in **negative number**
# - Duration of ride can not be be **zero** (which probably mean that ride was cancelled)

# %% [markdown]
# ### Removing rows with duration less than or equal to zero

# %%
used_df_v1=used_df_v1[used_df_v1.duration_of_ride_sec>0]

# %%
used_df_v1.duration_of_ride_sec.min()
# Out:
# 1.0

# %% [markdown]
# One second duration of ride? According to data source any ride having less than 1 min duration is a false data.

# %%
used_df_v1[used_df_v1.duration_of_ride_min<=1].head()
# Out:
#               ride_id rideable_type          started_at            ended_at  \
# 15   7DD70C4AA0F3EA7B  classic_bike 2022-01-14 05:47:07 2022-01-14 05:47:39
# 73   64CA42FCA02E5148  classic_bike 2022-01-12 14:37:54 2022-01-12 14:38:07
# 123  22096565E8AF075C  classic_bike 2022-01-14 16:10:37 2022-01-14 16:10:45
# 158  DB3BD626BB3253C9  classic_bike 2022-01-02 07:27:56 2022-01-02 07:28:00
# 203  B0F160012485900B  classic_bike 2022-01-10 07:28:27 2022-01-10 07:28:28
#
#                 start_station_name start_station_id  \
# 15       Lincoln Park Conservatory              LP-
# 73           State St & Pearson St     TA1307000061
# 123           Clinton St & Lake St            13021
# 158     Lincoln Ave & Waveland Ave            13253
# 203  Financial Pl & Ida B Wells Dr           SL-010
#
#                   end_station_name end_station_id  start_lat  start_lng  \
# 15       Lincoln Park Conservatory            LP-  41.923931 -87.635825
# 73           State St & Pearson St   TA1307000061  41.897448 -87.628722
# 123           Clinton St & Lake St          13021  41.885637 -87.641823
# 158     Lincoln Ave & Waveland Ave          13253  41.948797 -87.675278
# 203  Financial Pl & Ida B Wells Dr         SL-010  41.875024 -87.633094
#
#        end_lat    end_lng member_casual  duration_of_ride_sec  \
# 15   41.923931 -87.635825        member                  32.0
# 73   41.897448 -87.628722        member                  13.0
# 123  41.885637 -87.641823        member                   8.0
# 158  41.948797 -87.675278        member                   4.0
# 203  41.875024 -87.633094        member                   1.0
#
#      duration_of_ride_min  ride_start_in_years ride_start_in_month  \
# 15                   0.32                 2022             January
# 73                   0.13                 2022             January
# 123                  0.80                 2022             January
# 158                  0.40                 2022             January
# 203                  0.10                 2022             January
#
#      ride_start_in_quarter ride_start_in_weekday  ride_start_in_weekofmonth
# 15                       1                Friday                          3
# 73                       1             Wednesday                          3
# 123                      1                Friday                          3
# 158                      1                Sunday                          1
# 203                      1                Monday                          3

# %% [markdown]
# All the above data is irrelavant to us.

# %%
used_df_v1=used_df_v1[used_df_v1.duration_of_ride_min>1]

# %%
used_df_v1.shape
# Out:
# (5579838, 20)

# %% [markdown]
# ### Column Having Null Values

# %% [markdown]
# As the dataset contain enough data we can remove rows with null values without any worry because
# * Removing row will not make this dataset Bias
# * And even after deletion of rows, Dataset will represent whole Population

# %%
used_df_v1 =used_df_v1.dropna()

# %%
used_df_v1.shape
# Out:
# (4570069, 20)

# %%
sec=used_df_v1.duration_of_ride_sec.max()
sec
# used_df_v1.duration_of_ride_sec.max().time
# Out:
# 3356649.0

# %%
sec/(3600*24)
# Out:
# 38.85010416666667

# %% [markdown]
# As we can observe that this ride have a duration more than 38 days. Mean this ride was not made by the customer.

# %%
highest_duration=used_df_v1.sort_values(by=['duration_of_ride_sec'],ascending=False).head(50)

# %%
highest_duration.end_station_name.value_counts()
# Out:
# Base - 2132 W Hubbard Warehouse       13
# Lake Park Ave & 35th St                2
# Wentworth Ave & 35th St                1
# California Ave & Byron St              1
# Homewood Ave & 115th St                1
# Cicero Ave & Lake St                   1
# Kedzie Ave & Roosevelt Rd              1
# Clark St & Armitage Ave                1
# Central Park Ave & Ogden Ave           1
# Malcolm X College Vaccination Site     1
# Wabash Ave & Grand Ave                 1
# California Ave & Milwaukee Ave         1
# Michigan Ave & 8th St                  1
# California Ave & North Ave             1
# Union Ave & Root St                    1
# Western Ave & Walton St                1
# Fairfield Ave & Roosevelt Rd           1
# Clark St & Schiller St                 1
# Larrabee St & North Ave                1
# Damen Ave & Grand Ave                  1
# Michigan Ave & Lake St                 1
# Western Ave & Winnebago Ave            1
# Wells St & Polk St                     1
# Calumet Ave & 33rd St                  1
# Daley Center Plaza                     1
# Warren Park East                       1
# Wells St & Elm St                      1
# Columbus Dr & Randolph St              1
# Stony Island Ave & 82nd St             1
# South Shore Dr & 67th St               1
# Greenwood Ave & 79th St                1
# Clinton St & Madison St                1
# Clark St & Ida B Wells Dr              1
# Western Ave & Fillmore St              1
# MLK Jr Dr & 63rd St                    1
# Eberhart Ave & 91st St                 1
# Halsted St & Wrightwood Ave            1
# Name: end_station_name, dtype: int64

# %%
highest_duration.start_station_name.value_counts()
# Out:
# Millennium Park                       3
# Michigan Ave & Lake St                2
# Streeter Dr & Grand Ave               2
# California Ave & Division St          2
# Franklin St & Chicago Ave             2
# Michigan Ave & Oak St                 2
# Fort Dearborn Dr & 31st St            2
# DuSable Lake Shore Dr & Ohio St       2
# Fairbanks St & Superior St            2
# Dusable Harbor                        2
# Michigan Ave & Jackson Blvd           2
# Stockton Dr & Wrightwood Ave          1
# Central Ave & Lake St                 1
# Adler Planetarium                     1
# Cannon Dr & Fullerton Ave             1
# Lake Shore Dr & Monroe St             1
# State St & 19th St                    1
# Damen Ave & Melrose Ave               1
# LaSalle St & Washington St            1
# Michigan Ave & Ida B Wells Dr         1
# Clark St & North Ave                  1
# Clyde Ave & 87th St                   1
# Dearborn St & Adams St                1
# State St & 95th St                    1
# Montrose Harbor                       1
# Wabash Ave & Grand Ave                1
# Indiana Ave & Roosevelt Rd            1
# Throop St & 52nd St                   1
# Canal St & Adams St                   1
# DuSable Lake Shore Dr & North Blvd    1
# Central Ave & Harrison St             1
# State St & Kinzie St                  1
# Lake Shore Dr & Ohio St               1
# Wabash Ave & Wacker Pl                1
# Kedzie Ave & Milwaukee Ave            1
# Clark St & Lake St                    1
# State St & Van Buren St               1
# Buckingham Fountain                   1
# Name: start_station_name, dtype: int64

# %% [markdown]
# Some of the Rides were carried out to **Base - 2132 W Hubbard Warehouse** which is a warehouse. So we can conclude that these rides were carried out by the employees probably for repairing aur testing the bike.

# %%
used_df_v1[(used_df_v1.start_station_name=='Base - 2132 W Hubbard Warehouse') | (used_df_v1.end_station_name=='Base - 2132 W Hubbard Warehouse') ]
# Out:
#                   ride_id  rideable_type          started_at  \
# 681      FDE368CAD6D12721  electric_bike 2022-01-15 14:08:03
# 726      985CF16BB43CE5CB   classic_bike 2022-01-25 07:47:44
# 7838     EABC57FA1867F086  electric_bike 2022-01-30 01:03:40
# 8362     F879673E169CA896  electric_bike 2022-01-28 21:29:43
# 22958    CF753056C29F423E   classic_bike 2022-01-03 05:43:17
# ...                   ...            ...                 ...
# 5525441  6612A010C022CB16    docked_bike 2021-12-02 15:57:11
# 5525461  53F2A1BB5BFF0401  electric_bike 2021-12-02 21:34:47
# 5525503  11B2B57B5A5A018F  electric_bike 2021-12-07 08:43:13
# 5525534  B0500BDE7BD63888  electric_bike 2021-12-28 07:51:56
# 5525723  596C55BF4B051F46    docked_bike 2021-12-26 09:27:49
#
#                    ended_at               start_station_name  \
# 681     2022-01-15 14:11:46            Wood St & Chicago Ave
# 726     2022-01-25 08:47:30         Leavitt St & Division St
# 7838    2022-01-30 01:17:30  Base - 2132 W Hubbard Warehouse
# 8362    2022-01-28 21:46:58  Base - 2132 W Hubbard Warehouse
# 22958   2022-01-03 05:58:46            Ashland Ave & Lake St
# ...                     ...                              ...
# 5525441 2021-12-16 15:41:18          Damen Ave & Chicago Ave
# 5525461 2021-12-02 21:50:51           Wabash Ave & Grand Ave
# 5525503 2021-12-07 08:51:20            Ashland Ave & Lake St
# 5525534 2021-12-28 08:03:55        Western Ave & Division St
# 5525723 2021-12-27 13:28:33               Shore Dr & 55th St
#
#                             start_station_id                 end_station_name  \
# 681                                      637  Base - 2132 W Hubbard Warehouse
# 726                                      658  Base - 2132 W Hubbard Warehouse
# 7838     Hubbard Bike-checking (LBS-WH-TEST)           St Louis Ave & 59th St
# 8362     Hubbard Bike-checking (LBS-WH-TEST)             Kedzie Ave & 21st St
# 22958                                  13073  Base - 2132 W Hubbard Warehouse
# ...                                      ...                              ...
# 5525441                                13132  Base - 2132 W Hubbard Warehouse
# 5525461                         TA1307000117  Base - 2132 W Hubbard Warehouse
# 5525503                                13073  Base - 2132 W Hubbard Warehouse
# 5525534                                13241  Base - 2132 W Hubbard Warehouse
# 5525723                         TA1308000009  Base - 2132 W Hubbard Warehouse
#
#                               end_station_id  start_lat  start_lng    end_lat  \
# 681      Hubbard Bike-checking (LBS-WH-TEST)  41.895692 -87.672146  41.889955
# 726      Hubbard Bike-checking (LBS-WH-TEST)  41.902997 -87.683825  41.889955
# 7838                                     387  41.804769 -87.704078  41.790000
# 8362                                   15686  41.844621 -87.723278  41.853534
# 22958    Hubbard Bike-checking (LBS-WH-TEST)  41.885920 -87.667170  41.889955
# ...                                      ...        ...        ...        ...
# 5525441  Hubbard Bike-checking (LBS-WH-TEST)  41.895769 -87.677220  41.889955
# 5525461  Hubbard Bike-checking (LBS-WH-TEST)  41.891070 -87.626771  41.889926
# 5525503  Hubbard Bike-checking (LBS-WH-TEST)  41.885953 -87.667153  41.889937
# 5525534  Hubbard Bike-checking (LBS-WH-TEST)  41.902920 -87.687361  41.889955
# 5525723  Hubbard Bike-checking (LBS-WH-TEST)  41.795212 -87.580715  41.889955
#
#            end_lng member_casual  duration_of_ride_sec  duration_of_ride_min  \
# 681     -87.680651        member                 223.0                  3.43
# 726     -87.680651        member                3586.0                 59.46
# 7838    -87.710000        casual                 830.0                 13.50
# 8362    -87.705073        member                1035.0                 17.15
# 22958   -87.680651        member                 929.0                 15.29
# ...            ...           ...                   ...                   ...
# 5525441 -87.680651        casual             1208647.0              20144.70
# 5525461 -87.680203        member                 964.0                 16.40
# 5525503 -87.680255        member                 487.0                  8.70
# 5525534 -87.680651        member                 719.0                 11.59
# 5525723 -87.680651        casual              100844.0               1680.44
#
#          ride_start_in_years ride_start_in_month  ride_start_in_quarter  \
# 681                     2022             January                      1
# 726                     2022             January                      1
# 7838                    2022             January                      1
# 8362                    2022             January                      1
# 22958                   2022             January                      1
# ...                      ...                 ...                    ...
# 5525441                 2021            December                      4
# 5525461                 2021            December                      4
# 5525503                 2021            December                      4
# 5525534                 2021            December                      4
# 5525723                 2021            December                      4
#
#         ride_start_in_weekday  ride_start_in_weekofmonth
# 681                  Saturday                          3
# 726                   Tuesday                          5
# 7838                   Sunday                          5
# 8362                   Friday                          5
# 22958                  Monday                          2
# ...                       ...                        ...
# 5525441              Thursday                          1
# 5525461              Thursday                          1
# 5525503               Tuesday                          2
# 5525534               Tuesday                          5
# 5525723                Sunday                          4
#
# [628 rows x 20 columns]

# %% [markdown]
# ### Removing Rides which start or end at Base - 2132 W Hubbard Warehouse

# %%
used_df_v1=used_df_v1[~((used_df_v1.start_station_name=='Base - 2132 W Hubbard Warehouse') | (used_df_v1.end_station_name=='Base - 2132 W Hubbard Warehouse'))]

# %% [markdown]
# ### Calculating the quatile

# %% [markdown]
# Now we will find quatile range of the duration of ride to examine how rides are spread.

# %%
quartile_of_whole_data=(used_df_v1.duration_of_ride_min.quantile([i/100 for i in range(1,101)])).to_frame().reset_index()
quartile_of_whole_data['quartile']=quartile_of_whole_data['index']*100
quartile_of_whole_data.drop(['index'], axis = 1,inplace = True)
quartile_of_whole_data=quartile_of_whole_data.reindex(columns=['quartile','duration_of_ride_min'])
quartile_of_whole_data
# Out:
#     quartile  duration_of_ride_min
# 0        1.0                  1.55
# 1        2.0                  2.27
# 2        3.0                  2.46
# 3        4.0                  3.00
# 4        5.0                  3.23
# ..       ...                   ...
# 95      96.0                 66.13
# 96      97.0                 77.39
# 97      98.0                 95.13
# 98      99.0                130.11
# 99     100.0              55944.90
#
# [100 rows x 2 columns]

# %% [markdown]
# Above data confirm that 99 percent of ride are less than 131 minute.
# Now computing quatile range of data which is greater than 131 minute.

# %%
duration_greater_than_131=used_df_v1[used_df_v1.duration_of_ride_min>=131]
quartile_of_100=(duration_greater_than_131.duration_of_ride_min.quantile([i/10 for i in range(1,11)])).to_frame().reset_index()
quartile_of_100['quartile']=quartile_of_100['index']*100
quartile_of_100.drop(['index'], axis = 1,inplace = True)
quartile_of_100=quartile_of_100.reindex(columns=['quartile','duration_of_ride_min'])
# quartile_of_100[0:9]
quartile_of_100
# Out:
#    quartile  duration_of_ride_min
# 0      10.0               136.430
# 1      20.0               143.350
# 2      30.0               151.270
# 3      40.0               160.150
# 4      50.0               171.170
# 5      60.0               186.100
# 6      70.0               212.211
# 7      80.0               274.534
# 8      90.0               579.057
# 9     100.0             55944.900

# %%
sns.set_style('white')
sns.lineplot(data=quartile_of_100[0:9],y=quartile_of_100[0:9].duration_of_ride_min,x=quartile_of_100[0:9].quartile,color="black",linewidth=3)
plt.axvline(x=80,linestyle='--')
plt.axhline(y=275,linestyle='--')
plt.xlabel('Quartile')
plt.ylabel("Duration\n(min)")
plt.title("Quartile of Duration > 130")
plt.grid()

# %% [markdown]
# We can clearly see that after 80 percent the data is increasing drastically.
# **Conclusion:**
# Rows having duration(min) > 275 is consider outlier.

# %%
used_df_v1=used_df_v1[~(used_df_v1.duration_of_ride_min>275)]

# %% [markdown]
# ### Checkin for Duplicate rows

# %%
duplicate = used_df_v1[used_df_v1.duplicated()]
duplicate
# Out:
# Empty DataFrame
# Columns: [ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual, duration_of_ride_sec, duration_of_ride_min, ride_start_in_years, ride_start_in_month, ride_start_in_quarter, ride_start_in_weekday, ride_start_in_weekofmonth]
# Index: []

# %%
duplicateRowsDF = used_df_v1[used_df_v1.duplicated(['ride_id'])]
duplicateRowsDF
# Out:
# Empty DataFrame
# Columns: [ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual, duration_of_ride_sec, duration_of_ride_min, ride_start_in_years, ride_start_in_month, ride_start_in_quarter, ride_start_in_weekday, ride_start_in_weekofmonth]
# Index: []

# %% [markdown]
# # Checking for Mis-spelling

# %%
used_df_v1.rideable_type.unique()
# Out:
# array(['electric_bike', 'classic_bike', 'docked_bike'], dtype=object)

# %%
used_df_v1.member_casual.unique()
# Out:
# array(['casual', 'member'], dtype=object)

# %% [markdown]
# There is no spelling mistake in columns so we can end cleaning process.

# %% [markdown]
# # Saving Dataframe In New File

# %%
used_df_v1.to_csv("../datasets/clean_main_df.csv")

# %% [markdown]
# # Trash

# %%
# sns.countplot(data=used_df_v2,x='rideable_type',hue='member_casual')
# plt.title("Categories Wise Bike Used in Last 12 Months")
# plt.ticklabel_format(style='plain', axis='y')
# plt.xlabel('Bike Type')
# plt.ylabel('Number of Time Bike Used')
# sns.set_style('white')
# plt.savefig('g.png')
# plt.show()

# %%
# sns.set_style('darkgrid')
# sns.catplot(x="rideable_type", kind = "count", data=used_df_v2,row='month')

# plt.ticklabel_format(style='plain', axis='y')
# plt.xlabel('Bike Type')
# plt.ylabel('Number of Time Bike Used')
# plt.savefig("squares.png")
# plt.show()

# %%
# # Form a facetgrid using columns with a hue
# graph = sns.FacetGrid(used_df_v2, col ='month')
# # map the above form facetgrid with some attributes
# graph.map(sns.catplot, 'rideable_type',kind = "count")
# # show the object
# plt.show()

# %%
# g = sns.factorplot("month", data=used_df_v2, aspect=4.0, kind='count',
#                        hue='rideable_type')
# plt.show()

# %%
# used_df_v1.isna().sum()

# %% [markdown]
# We can clearly see that start_station_name null values are not equal to start_station_id mean we can fill this data.
# if dataset have start_station_name we can try to extract it start_station_id will the help of other rows of dataset and vice versa.

# %% [markdown]
# * Step 1 check does dataset have rows in which only one of these column have null value.

# %%
# def two_column_one_na(dataframe,first_col,second_col):
#     return dataframe[(pd.isna(dataframe[first_col]) & pd.notna(dataframe[second_col]))
#                 | 
#                 (pd.notna(dataframe[first_col]) & pd.isna(dataframe[second_col]))]
# two_column_one_na(used_df_v2,'start_station_name','start_station_id')
# two_column_one_na(used_df_v2,'end_station_name','end_station_id')

# %%
# def handling_depending_Na_value(dataframe,first_col,second_col):
#     dic={}
#     for index, row in dataframe.iterrows():
#         if pd.notnull(row[first_col]) and pd.notnull(row[second_col]):       
#             if row[first_col] not in dic:
#                 dic[row[first_col]]=row[second_col]

#     for index, row in dataframe.iterrows():
#         if pd.notnull(row[first_col]) ^ pd.notnull(row[second_col]):
#             if pd.notnull(row[first_col]):
#                 dataframe.loc[index,second_col]=dic[row[first_col]]
#             elif pd.notnull(row[second_col]):
#                 for i, j in dic.items():
#                     if j== row[second_col]:
#                         dataframe.loc[index,first_col]=i

# handling_depending_Na_value(used_df_v2,'start_station_name','start_station_id')
